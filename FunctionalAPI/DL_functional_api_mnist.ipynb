# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input , Dense
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.datasets import mnist
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(x_train.shape[0], 784)
x_test = x_test.reshape(x_test.shape[0], 784)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

x_train/=255
x_test/=255

number_of_classes = 10
from keras.utils import np_utils
y_train = np_utils.to_categorical(y_train, number_of_classes)
y_test = np_utils.to_categorical(y_test, number_of_classes)

print(x_train.shape)
# Out:
# (60000, 784)

# %%
input_layer = Input(shape=(784 , ))
Layer_1 = Dense(64 , activation ="relu")(input_layer)
Layer_2 = Dense(64 , activation ="relu")(Layer_1)
Layer_2 = Dense(64 , activation ="relu")(Layer_2)
output_layer = Dense(10 , activation="softmax")(Layer_2)

model = Model(inputs=input_layer , outputs=output_layer)
#model.add(Conv2D(32, (5,5) , padding='valid' , strides= (2,2) , input_shape= (28,28,1) , activation='relu'))
#model.add(MaxPooling2D(pool_size=(2,2)))
#model.add(Dropout(0.2))
#model.add(Flatten())
#model.add(Dense ( 128 , activation='relu'))
#model.add(Dense(10 , activation='softmax'))

model.compile(loss='categorical_crossentropy' , optimizer='adam' , metrics=['accuracy'])
model.build(x_train.shape)
model.summary()
# Out:
# Model: "model_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_19 (InputLayer)       [(None, 784)]             0
#
#  dense_69 (Dense)            (None, 64)                50240
#
#  dense_70 (Dense)            (None, 64)                4160
#
#  dense_71 (Dense)            (None, 64)                4160
#
#  dense_72 (Dense)            (None, 10)                650
#
# ...
# Total params: 59,210
# Trainable params: 59,210
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train , y_train , epochs=20)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2714 - accuracy: 0.9187
# Epoch 2/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1266 - accuracy: 0.9621
# Epoch 3/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0925 - accuracy: 0.9715
# Epoch 4/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0741 - accuracy: 0.9760
# Epoch 5/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0599 - accuracy: 0.9809
# Epoch 6/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0520 - accuracy: 0.9829
# Epoch 7/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0446 - accuracy: 0.9855
# Epoch 8/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0372 - accuracy: 0.9882
# Epoch 9/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0343 - accuracy: 0.9889
# Epoch 10/20
# ...
