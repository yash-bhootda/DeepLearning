# %%
# %%writefile first.cpp
# #include<iostream>
# using namespace std;
# int main()
# {
#     cout<<"Hello";
# }
# Out:
# Overwriting first.cpp

# %%
# %%script bash
# g++ first.cpp -o first.out
# ./first.out
# Out:
# Hello
