# %%
import datetime
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.callbacks import TensorBoard

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

model = Sequential([
    Flatten(input_shape=(32, 32 , 3)),
    Dense(512, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
 

time = "logs/fit/"  #datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
log_dir = f"logs/{time}"
tensorboard = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1) # added
print(log_dir)
 

model.fit(
    x=x_train,
    y=y_train,
    epochs=15,
    validation_data=(x_test, y_test),
    callbacks=[tensorboard]
    )
 

 

 

# %load_ext tensorboard
 

 

# %tensorboard --logdir  /content/logs/logs/fit
# Out:
# logs/logs/fit/
# Epoch 1/15
# 1563/1563 [==============================] - 25s 16ms/step - loss: 1.9546 - accuracy: 0.2899 - val_loss: 1.7754 - val_accuracy: 0.3667
# Epoch 2/15
# 1563/1563 [==============================] - 25s 16ms/step - loss: 1.8347 - accuracy: 0.3311 - val_loss: 1.7319 - val_accuracy: 0.3805
# Epoch 3/15
# 1563/1563 [==============================] - 24s 16ms/step - loss: 1.7940 - accuracy: 0.3484 - val_loss: 1.7108 - val_accuracy: 0.3816
# Epoch 4/15
# 1563/1563 [==============================] - 25s 16ms/step - loss: 1.7697 - accuracy: 0.3594 - val_loss: 1.6703 - val_accuracy: 0.4031
# Epoch 5/15
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.7423 - accuracy: 0.3674 - val_loss: 1.6441 - val_accuracy: 0.4109
# Epoch 6/15
# 1563/1563 [==============================] - 25s 16ms/step - loss: 1.7329 - accuracy: 0.3738 - val_loss: 1.6800 - val_accuracy: 0.3982
# Epoch 7/15
# 1563/1563 [==============================] - 24s 15ms/step - loss: 1.7126 - accuracy: 0.3800 - val_loss: 1.6518 - val_accuracy: 0.4055
# Epoch 8/15
# 1563/1563 [==============================] - 24s 15ms/step - loss: 1.7059 - accuracy: 0.3845 - val_loss: 1.6186 - val_accuracy: 0.4182
# Epoch 9/15
# 1563/1563 [==============================] - 25s 16ms/step - loss: 1.7000 - accuracy: 0.3855 - val_loss: 1.6176 - val_accuracy: 0.4192
# Epoch 10/15
# 1563/1563 [==============================] - 23s 15ms/step - loss: 1.6898 - accuracy: 0.3883 - val_loss: 1.6313 - val_accuracy: 0.4163
# Epoch 11/15
# 1563/1563 [==============================] - 23s 14ms/step - loss: 1.6848 - accuracy: 0.3901 - val_loss: 1.6005 - val_accuracy: 0.4291
# Epoch 12/15
# 1563/1563 [==============================] - 23s 15ms/step - loss: 1.6739 - accuracy: 0.3968 - val_loss: 1.5899 - val_accuracy: 0.4356
# Epoch 13/15
# 1563/1563 [==============================] - 24s 15ms/step - loss: 1.6659 - accuracy: 0.3984 - val_loss: 1.5990 - val_accuracy: 0.4344
# Epoch 14/15
# 1563/1563 [==============================] - 25s 16ms/step - loss: 1.6619 - accuracy: 0.4012 - val_loss: 1.5915 - val_accuracy: 0.4321
# Epoch 15/15
# 1563/1563 [==============================] - 23s 15ms/step - loss: 1.6554 - accuracy: 0.4037 - val_loss: 1.5536 - val_accuracy: 0.4489
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 163), started 0:40:16 ago. (Use '!kill 163' to kill it.)
