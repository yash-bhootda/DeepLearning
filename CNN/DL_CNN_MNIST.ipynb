# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.datasets import mnist
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

x_train/=255
x_test/=255

number_of_classes = 10
a=10
from keras.utils import np_utils
y_train = np_utils.to_categorical(y_train, number_of_classes  )
y_test = np_utils.to_categorical(y_test, number_of_classes )

print(x_train.shape)
# Out:
# (50000, 32, 32, 3)

# %%
def baseline_model():
  model=Sequential()
  model.add(Conv2D(32, (5,5) , padding='valid' , strides= (2,2) , input_shape= (28,28,1) , activation='relu'))
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(Dropout(0.2))
  model.add(Flatten())
  model.add(Dense ( 128 , activation='relu'))
  model.add(Dense(10 , activation='softmax'))

  model.compile(loss='categorical_crossentropy' , optimizer='adam' , metrics=['accuracy'])
  return model

# %%
model=baseline_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 12, 12, 32)        832
#
#  max_pooling2d (MaxPooling2D  (None, 6, 6, 32)         0
#  )
#
#  dropout (Dropout)           (None, 6, 6, 32)          0
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 128)               147584
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 149,706
# Trainable params: 149,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train , y_train , epochs=20)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.1965 - accuracy: 0.9412
# Epoch 2/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0738 - accuracy: 0.9775
# Epoch 3/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0523 - accuracy: 0.9833
# Epoch 4/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0418 - accuracy: 0.9869
# Epoch 5/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0329 - accuracy: 0.9896
# Epoch 6/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0282 - accuracy: 0.9908
# Epoch 7/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0232 - accuracy: 0.9924
# Epoch 8/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0212 - accuracy: 0.9925
# Epoch 9/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0192 - accuracy: 0.9936
# Epoch 10/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0149 - accuracy: 0.9951
# Epoch 11/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0153 - accuracy: 0.9947
# Epoch 12/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0125 - accuracy: 0.9959
# Epoch 13/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0120 - accuracy: 0.9958
# Epoch 14/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0115 - accuracy: 0.9960
# Epoch 15/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0102 - accuracy: 0.9963
# Epoch 16/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0094 - accuracy: 0.9968
# Epoch 17/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0094 - accuracy: 0.9967
# Epoch 18/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0094 - accuracy: 0.9965
# Epoch 19/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0081 - accuracy: 0.9969
# Epoch 20/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0075 - accuracy: 0.9973
